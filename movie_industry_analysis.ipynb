# %%
#This project is a version for the one shared on the YT channel Alex the Analyst: https://www.youtube.com/watch?v=iPYVYBtUTyE&t=239s 
#source: https://www.kaggle.com/danielgrijalvas/movies/version/2

import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

#data
df = pd.read_csv('movies.csv')

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
import numpy as np

# %%
#Check for missing data
for c in df.columns:
    percent_missing = np.mean(df[c].isnull())
    print(f'{c} - {percent_missing}')
# Out:
# name - 0.0
# rating - 0.010041731872717789
# genre - 0.0
# year - 0.0
# released - 0.0002608242044861763
# score - 0.0003912363067292645
# votes - 0.0003912363067292645
# director - 0.0
# writer - 0.0003912363067292645
# star - 0.00013041210224308815
# country - 0.0003912363067292645
# budget - 0.2831246739697444
# gross - 0.02464788732394366
# company - 0.002217005738132499
# runtime - 0.0005216484089723526

# %%
#Check columns types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Change budget and gross to int type
df['budget'].fillna('0',inplace = True)
df['gross'].fillna('0',inplace = True)
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
#Get just the year of release
df['year_corrected'] = df['released'].astype(str).str.extract(r'(\d{4})')

# %%
df.sort_values(by=['gross'],inplace=False, ascending = False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
pd.set_option('display.max_rows',50)

# %%
# Show duplicated values for company
print(df['company'].drop_duplicates().sort_values())
# Out:
# 4345        "DIA" Productions GmbH & Co. KG
# 7525    "Weathering With You" Film Partners
# 3024                        .406 Production
# 3748                     1+2 Seisaku Iinkai
# 5813                        10 West Studios
#                        ...
# 4007                               i5 Films
# 6412               iDeal Partners Film Fund
# 5664                            micro_scope
# 7129                                thefyzz
# 408                                     NaN
# Name: company, Length: 2386, dtype: object

# %%
#Checking correlations between some of the variables and the revenue
#First Scatter PLot Budget Vs Gross Reveneue

plt.scatter(x = df[(df['budget'] != 0)&(df['gross'] != 0)]['budget'],y =df[(df['budget'] != 0)&(df['gross'] != 0)]['gross'])
plt.title('Budget Vs Gross Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %%
#Create a Regression plot for Budget Vs Gross Revenue

sns.regplot(x = 'budget',y ='gross',data =  df, scatter_kws ={'color':'black'},line_kws ={'color':'green'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Check Correlations - PEarson - raw numerical fields
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
#Visualize the Pearson Correlation Scores
corr_matrix = df.corr()
sns.heatmap(corr_matrix,annot = True)
plt.title('Correlation Plot')
plt.xlabel('Features')
plt.ylabel('Features')
plt.show()

# %%
#Check on the companies factor on the Budget - Company is not numerical though  - need to be changed to Numerical
# We actually numerize all the columns which are not Numerical
df_numerized = df.copy(deep = True)
for c in df_numerized.columns:
    if df_numerized[c].dtype =='object':
        df_numerized[c] = df_numerized[c].astype('category')
        df_numerized[c] = df_numerized[c].cat.codes
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
#Correlation matrix with the numerized version of DF
corr_matrix = df_numerized.corr()
sns.heatmap(corr_matrix,annot = True)
plt.title('Correlation Plot')
plt.xlabel('Features')
plt.ylabel('Features')
plt.show()

# %%
#Filter the graph for gross only
corr_pairs = corr_matrix.unstack()
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget          genre            -0.334021
# genre           budget           -0.334021
#                 gross            -0.234297
# gross           genre            -0.234297
# votes           genre            -0.145307
#                                     ...
# year            year              1.000000
# genre           genre             1.000000
# rating          rating            1.000000
# runtime         runtime           1.000000
# year_corrected  year_corrected    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross           votes             0.632834
# votes           gross             0.632834
# gross           budget            0.750157
# budget          gross             0.750157
# year_corrected  year              0.996397
# year            year_corrected    0.996397
# name            name              1.000000
# company         company           1.000000
# gross           gross             1.000000
# budget          budget            1.000000
# country         country           1.000000
# star            star              1.000000
# writer          writer            1.000000
# director        director          1.000000
# votes           votes             1.000000
# score           score             1.000000
# released        released          1.000000
# year            year              1.000000
# genre           genre             1.000000
# rating          rating            1.000000
# runtime         runtime           1.000000
# year_corrected  year_corrected    1.000000
# ...
